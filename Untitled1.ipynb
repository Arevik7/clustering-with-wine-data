# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'~/Downloads/Wine.csv', error_bad_lines=False)
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
##there is no nulls in data
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %%
##there is no dublications in data
sum(df.duplicated())
# Out:
# 0

# %%
plt.figure(figsize=(15,15))
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
sns.heatmap(df.corr(), cmap=cmap, cbar_kws={'shrink': .8}, square=True, annot=True, fmt='.2f', linewidths=.8)
plt.show()

# %%
import plotly.offline as pyo
import plotly.figure_factory as ff
from plotly import tools
from plotly.subplots import make_subplots
import os
import chart_studio.plotly as py


import plotly.graph_objs as go

sns.set(rc={'figure.figsize':(10,6)})
sns.set(font_scale=1.3)
plt.style.use('fivethirtyeight')

from sklearn.model_selection import train_test_split


from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier

from sklearn.metrics import accuracy_score

# %%
import matplotlib.gridspec as gridspec
fig1 = plt.figure(constrained_layout=True, figsize = (20,15))
spec1 = gridspec.GridSpec(ncols=4, nrows=4, figure=fig1)
f1_ax1 = fig1.add_subplot(spec1[0, 0])
f1_ax1.boxplot(df["Alcohol"])
f1_ax2 = fig1.add_subplot(spec1[0, 1])
f1_ax2.boxplot(df["Malic_Acid"])
f1_ax3 = fig1.add_subplot(spec1[1, 0])
f1_ax3.boxplot(df["Ash"])
f1_ax4 = fig1.add_subplot(spec1[1, 1])
f1_ax4.boxplot(df["Ash_Alcanity"])
f1_ax5 = fig1.add_subplot(spec1[0, 2])
f1_ax5.boxplot(df["Proanthocyanins"])
f1_ax6 = fig1.add_subplot(spec1[1, 2])
f1_ax6.boxplot(df["Magnesium"])
f1_ax7 = fig1.add_subplot(spec1[2, 2])
f1_ax7.boxplot(df["Total_Phenols"])
f1_ax8 = fig1.add_subplot(spec1[2, 0])
f1_ax8.boxplot(df["Flavanoids"])
f1_ax9 = fig1.add_subplot(spec1[2, 1])
f1_ax9.boxplot(df["Nonflavanoid_Phenols"])
f1_ax10 = fig1.add_subplot(spec1[0, 3])
f1_ax10.boxplot(df["Hue"])
f1_ax11 = fig1.add_subplot(spec1[1, 3])
f1_ax11.boxplot(df["Color_Intensity"])
f1_ax12 = fig1.add_subplot(spec1[2, 3])
f1_ax12.boxplot(df["OD280"])

##There some outliers in the following features.
##Ash
##Ash_Alcanity
##Magnesium
##Proanthocyanins
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x123c4d6d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x123c4dd90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x123c4d5e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x123c59490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x123c597f0>],
#  'means': []}

# %%
sns.set(style="whitegrid")
df.iloc[:,0:13].boxplot(figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
# skewness along the index axis 
##verify Skewness in data

##Skewness is a measure of asymmetry of a distribution.
##If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
##If the skewness is between -1 and — 0.5 or between 0.5 and 1, the data are moderately skewed
##If the skewness is less than -1 or greater than 1, the data are highly skewed
df.skew(axis = 0, skipna = True)
##The features:Magnesium and Malic_Acid are highly skewed and hence should be transformed
# Out:
# Alcohol                -0.051482
# Malic_Acid              1.039651
# Ash                    -0.176699
# Ash_Alcanity            0.213047
# Magnesium               1.098191
# Total_Phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid_Phenols    0.450151
# Proanthocyanins         0.517137
# Color_Intensity         0.868585
# Hue                     0.021091
# OD280                  -0.307285
# Proline                 0.767822
# Customer_Segment        0.107431
# dtype: float64

# %%
df['Customer_Segment'].value_counts(sort = False, normalize = True)*100
##Customer Segment looks like balanced with 3 different types. No imabalance treatment required
# Out:
# 1    33.146067
# 2    39.887640
# 3    26.966292
# Name: Customer_Segment, dtype: float64

# %%
plt.figure(figsize=(12,6))
contagem = df['Customer_Segment'].value_counts()

ax = sns.countplot(data=df, x='Customer_Segment')

for c in ax.patches:
    ax.text(c.get_x() + c.get_width() / 2, c.get_height() + 0.9, c.get_height(), fontsize='16')
    
ax.set_xlabel('N° of Segment', fontsize = 15)
ax.set_ylabel('Count', fontsize = 15);

# %%
df.columns
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline',
#        'Customer_Segment'],
#       dtype='object')

# %%
import datetime
import numpy as np
import pandas as pd
import scipy

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
customer=df['Customer_Segment']

# %%
# Standardizing data

cluster_data = df.drop(columns='Customer_Segment')
scaler = StandardScaler()
data_stand = scaler.fit_transform(cluster_data)

# %%
hier_clust = linkage(data_stand, method = 'ward')
# We plot the results from the Hierarchical Clustering using a Dendrogram. 
plt.figure(figsize = (12,9))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(hier_clust,
           truncate_mode = 'level', 
           p = 5,
           no_labels = True)
plt.show()

# %%
# Loop and count Within Cluster Sum of Squares
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i,  random_state = 42)
    kmeans.fit(data_stand)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize = (10,8))
plt.plot(range(1, 11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means Clustering')
plt.show()

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
kmeans.fit(data_stand)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
segm_labels = cluster_data.copy()
segm_labels['Segments'] = kmeans.labels_
segm_labels.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-c91750f07b56> in <module>
# ----> 1 segm_labels = customer_data.copy()
#       2 segm_labels['Segments'] = kmeans.labels_
#       3 segm_labels.head(100)
#
# NameError: name 'customer_data' is not defined

# %%
profiling = segm_labels.groupby(['Segments'], as_index=False).mean()
profiling
##Segment profiling shows the average of each variable for each cluster. Let's call the first cluster “promising”. Customers in this segment have low recency score, average frequency, and monetary value scores. Customers in second cluster are the churners. Basically, they only bought once in their lifetime, have small checks and never returned. The third segment is potentially good customers who are likely to come back and spend a lot of money. And last but not least, loyal customers with low recency score, high frequency, and monetary value. We call them “champions”.
# Out:
#    Segments    Alcohol  Malic_Acid       Ash  Ash_Alcanity   Magnesium  \
# 0         0  13.676774    1.997903  2.466290     17.462903  107.967742
# 1         1  13.134118    3.307255  2.417647     21.241176   98.666667
# 2         2  12.250923    1.897385  2.231231     20.063077   92.738462
#
#    Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# 0       2.847581    3.003226              0.292097         1.922097
# 1       1.683922    0.818824              0.451961         1.145882
# 2       2.247692    2.050000              0.357692         1.624154
#
#    Color_Intensity       Hue     OD280      Proline
# 0         5.453548  1.065484  3.163387  1100.225806
# 1         7.234706  0.691961  1.696667   619.058824
# 2         2.973077  1.062708  2.803385   510.169231

# %%
#Create new columns: Segment size and Segment proportion 
profiling['Segment_size'] = segm_labels.groupby(['Segments'])['Segments'].count()
profiling['Segment_prop'] = round(profiling['Segment_size'] / profiling['Segment_size'].sum() * 100, 2)

# Add the segment labels to our table
profiling['Segments'] = profiling['Segments'].map({0:"Type1",
                                                  1:"Type2",
                                                  2:"Type3"})

profiling
# Out:
#   Segments    Alcohol  Malic_Acid       Ash  Ash_Alcanity   Magnesium  \
# 0    Type1  13.676774    1.997903  2.466290     17.462903  107.967742
# 1    Type2  13.134118    3.307255  2.417647     21.241176   98.666667
# 2    Type3  12.250923    1.897385  2.231231     20.063077   92.738462
#
#    Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# 0       2.847581    3.003226              0.292097         1.922097
# 1       1.683922    0.818824              0.451961         1.145882
# 2       2.247692    2.050000              0.357692         1.624154
#
#    Color_Intensity       Hue     OD280      Proline  Segment_size  \
# 0         5.453548  1.065484  3.163387  1100.225806            62
# 1         7.234706  0.691961  1.696667   619.058824            51
# 2         2.973077  1.062708  2.803385   510.169231            65
#
#    Segment_prop
# 0         34.83
# 1         28.65
# 2         36.52

# %%
x_axis = segm_labels['Proline']
y_axis = segm_labels['Malic_Acid']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = segm_labels['Segments'], palette = ['g', 'r', 'c'])
plt.title('Segmentation K-means')
plt.show()

# %%
segm_labels['Segments'] = segm_labels['Segments'].map({0:"Type1",
                                                  1:"Type2",
                                                  2:"Type3"})

segm_labels.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline Segments
# 0   3.92     1065    Type1
# 1   3.40     1050    Type1
# ...

# %%
x_axis = segm_labels['Alcohol']
y_axis = segm_labels['Flavanoids']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = segm_labels['Segments'], palette = ['g', 'r', 'c'])
plt.title('Segmentation K-means')
plt.show()

# %%
x_axis = segm_labels['Color_Intensity']
y_axis = segm_labels['Hue']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = segm_labels['Segments'], palette = ['g', 'r', 'c'])
plt.title('Segmentation K-means')
plt.show()

# %%
x_axis = segm_labels['Flavanoids']
y_axis = segm_labels['Color_Intensity']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = segm_labels['Segments'], palette = ['g', 'r', 'c'])
plt.title('Segmentation K-means')
plt.show()

# %%
segm_labels=segm_labels.join(customer)

# %%
segm_labels
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
import matplotlib.gridspec as gridspec
fig1 = plt.figure(constrained_layout=True, figsize = (15,10))
spec2 = gridspec.GridSpec(ncols=3, nrows=2, figure=fig1)
f3_ax1 = fig1.add_subplot(spec2[0, 1])
g1 = sns.countplot(x = 'Customer_Segment', data = segm_labels, palette = ('#B32400',"#FF9980"), ax = f3_ax1)
f3_ax1.set_title('first')
f3_ax1.tick_params(axis='x', labelrotation = 90)
f3_ax2 = fig1.add_subplot(spec2[0, 2])
g2 = sns.countplot(x='Segments', data =segm_labels ,palette = ('#FF0000',"#FF8080",'#990000'), ax = f3_ax2)
f3_ax2.set_title('second')
# Out:
# Text(0.5, 1.0, 'second')

# %%
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(data_stand)
pca.explained_variance_ratio_
# Out:
# array([0.36198848, 0.1920749 , 0.11123631, 0.0706903 , 0.06563294,
#        0.04935823, 0.04238679, 0.02680749, 0.02222153, 0.01930019,
#        0.01736836, 0.01298233, 0.00795215])

# %%
data_stand
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
plt.figure(figsize = (15,10))
plt.plot(range(1,14), np.array(pca.explained_variance_ratio_).cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
pca = PCA(n_components = 3)
pca.fit(data_stand)
# Out:
# PCA(n_components=3)

# %%
##pca results
df_pca_comp = pd.DataFrame(data = pca.components_,
                           columns = cluster_data.columns.values,
                           index = ['Component 1', 'Component 2', 'Component 3'])
df_pca_comp
# Out:
#               Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Component 1  0.144329   -0.245188 -0.002051     -0.239320   0.141992
# Component 2 -0.483652   -0.224931 -0.316069      0.010591  -0.299634
# Component 3 -0.207383    0.089013  0.626224      0.612080   0.130757
#
#              Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# Component 1       0.394661    0.422934             -0.298533         0.313429
# Component 2      -0.065040    0.003360             -0.028779        -0.039302
# Component 3       0.146179    0.150682              0.170368         0.149454
#
#              Color_Intensity       Hue     OD280   Proline
# Component 1        -0.088617  0.296715  0.376167  0.286752
# Component 2        -0.529996  0.279235  0.164496 -0.364903
# Component 3        -0.137306  0.085222  0.166005 -0.126746

# %%
sns.heatmap(df_pca_comp,
            vmin = -1, 
            vmax = 1,
            cmap = 'RdBu',
            annot = True)
plt.yticks([0, 1, 2], 
           ['Component 1', 'Component 2', 'Component 3'],
           rotation = 45,
           fontsize = 9)
# Out:
# ([<matplotlib.axis.YTick at 0x126c4aca0>,
# ...
#  [Text(0, 0, 'Component 1'),
#   Text(0, 1, 'Component 2'),
#   Text(0, 2, 'Component 3')])

# %%
pca_results = pca.transform(data_stand)

# %%
##k-means clustering with pca data
# We fit K means using the transformed data from the PCA.
wcss = []
for i in range(1,14):
    kmeans_pca = KMeans(n_clusters = i, random_state = 42)
    kmeans_pca.fit(pca_results)
    wcss.append(kmeans_pca.inertia_)

# %%
# Plot the Within Cluster Sum of Squares for the K-means PCA model. Here we make a decission about the number of clusters.
# Again it looks like four is the best option.
plt.figure(figsize = (10,8))
plt.plot(range(1, 14), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-means with PCA Clustering')
plt.show()

# %%
kmeans_pca = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
kmeans_pca.fit(pca_results)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
pca_frame = pd.DataFrame(pca_results, columns=['Component 1', 'Component 2', 'Component 3'])
final_data = pd.concat([cluster_data.reset_index(drop = True), pca_frame],  axis = 1)
final_data['Segments'] = kmeans_pca.labels_

# %%
segm_labels = cluster_data.copy()
segm_labels['Segments'] = kmeans.labels_
segm_labels.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Segments
# 0   3.92     1065         0
# 1   3.40     1050         0
# ...

# %%
profiling = final_data.groupby(['Segments'], as_index=False).mean()

profiling['Segment_size'] = final_data.groupby(['Segments'])['Segments'].count()
profiling['Segment_prop'] = round(profiling['Segment_size'] / profiling['Segment_size'].sum() * 100, 2)

profiling
# Out:
#    Segments    Alcohol  Malic_Acid       Ash  Ash_Alcanity   Magnesium  \
# 0         0  13.134118    3.307255  2.417647     21.241176   98.666667
# 1         1  13.656032    1.983175  2.460476     17.479365  107.650794
# 2         2  12.249062    1.910312  2.233281     20.087500   92.812500
#
#    Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# 0       1.683922    0.818824              0.451961         1.145882
# 1       2.858254    3.015079              0.291270         1.922540
# 2       2.227813    2.023438              0.359531         1.619063
#
#    Color_Intensity       Hue     OD280      Proline  Component 1  Component 2  \
# 0         7.234706  0.691961  1.696667   619.058824    -2.720036    -1.125651
# 1         5.438413  1.065079  3.157143  1093.238095     2.275808    -0.894518
# 2         2.949219  1.063063  2.803906   507.828125    -0.072720     1.777544
#
#    Component 3  Segment_size  Segment_prop
# 0    -0.239093            51         28.65
# ...

# %%
# Add the segment labels to our table
profiling['Segments'] = profiling['Segments'].map({0:'Type_1', 
                                                   1:'Type_2',
                                                   2:'Type_3'})

profiling
# Out:
#   Segments    Alcohol  Malic_Acid       Ash  Ash_Alcanity   Magnesium  \
# 0   Type_1  13.134118    3.307255  2.417647     21.241176   98.666667
# 1   Type_2  13.656032    1.983175  2.460476     17.479365  107.650794
# 2   Type_3  12.249062    1.910312  2.233281     20.087500   92.812500
#
#    Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# 0       1.683922    0.818824              0.451961         1.145882
# 1       2.858254    3.015079              0.291270         1.922540
# 2       2.227813    2.023438              0.359531         1.619063
#
#    Color_Intensity       Hue     OD280      Proline  Component 1  Component 2  \
# 0         7.234706  0.691961  1.696667   619.058824    -2.720036    -1.125651
# 1         5.438413  1.065079  3.157143  1093.238095     2.275808    -0.894518
# 2         2.949219  1.063063  2.803906   507.828125    -0.072720     1.777544
#
#    Component 3  Segment_size  Segment_prop
# 0    -0.239093            51         28.65
# ...

# %%
# Add the segment labels to our table
final_data['Segments'] = final_data['Segments'].map({0:'Type_1', 
                                                   1:'Type_2',
                                                   2:'Type_3'})



final_data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Component 1  Component 2  Component 3 Segments
# ...

# %%
x_axis = final_data['Component 2']
y_axis = final_data['Component 1']
plt.figure(figsize = (10, 8))
sns.scatterplot(x_axis, y_axis, hue = final_data['Segments'], palette = ['g', 'r', 'c'])
plt.title('Clusters by PCA Components')
plt.show()

# %%
segm_labels.columns
